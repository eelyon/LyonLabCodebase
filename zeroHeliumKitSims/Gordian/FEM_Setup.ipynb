# %% [markdown]
# # Install Packages

# %%
pip install -e ./lib/quantum_electron-main/quantum_electron-main/
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///C:/Users/gordi/Princeton%20Dropbox/Gordian%20Fuchs/GroupDropbox/Gordian/Python/zeroHeliumKitSimulations/Gordian/lib/quantum_electron-main/quantum_electron-main
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting shapely (from quantum_electron==0.2.2)
#   Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\lib\site-packages (from quantum_electron==0.2.2) (0.23.2)
# Collecting pyvista (from quantum_electron==0.2.2)
#   Downloading pyvista-0.46.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: IPython in c:\programdata\anaconda3\lib\site-packages (from quantum_electron==0.2.2) (8.25.0)
# Collecting alive_progress (from quantum_electron==0.2.2)
#   Using cached alive_progress-3.3.0-py3-none-any.whl.metadata (72 kB)
# Collecting about-time==4.2.1 (from alive_progress->quantum_electron==0.2.2)
#   Using cached about_time-4.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting graphemeu==0.7.2 (from alive_progress->quantum_electron==0.2.2)
#   Using cached graphemeu-0.7.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (5.14.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from IPython->quantum_electron==0.2.2) (0.4.6)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from pyvista->quantum_electron==0.2.2) (3.8.4)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\lib\site-packages (from pyvista->quantum_electron==0.2.2) (1.26.4)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from pyvista->quantum_electron==0.2.2) (10.3.0)
# Collecting pooch (from pyvista->quantum_electron==0.2.2)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting scooby>=0.5.1 (from pyvista->quantum_electron==0.2.2)
#   Downloading scooby-0.11.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.10 in c:\programdata\anaconda3\lib\site-packages (from pyvista->quantum_electron==0.2.2) (4.11.0)
# Collecting vtk!=9.4.0 (from pyvista->quantum_electron==0.2.2)
#   Downloading vtk-9.5.2-cp312-cp312-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: scipy>=1.9 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->quantum_electron==0.2.2) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->quantum_electron==0.2.2) (3.2.1)
# Requirement already satisfied: imageio>=2.33 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->quantum_electron==0.2.2) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->quantum_electron==0.2.2) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->quantum_electron==0.2.2) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->quantum_electron==0.2.2) (0.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->IPython->quantum_electron==0.2.2) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.1->pyvista->quantum_electron==0.2.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.1->pyvista->quantum_electron==0.2.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.1->pyvista->quantum_electron==0.2.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.1->pyvista->quantum_electron==0.2.2) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.1->pyvista->quantum_electron==0.2.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.1->pyvista->quantum_electron==0.2.2) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->quantum_electron==0.2.2) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\programdata\anaconda3\lib\site-packages (from pooch->pyvista->quantum_electron==0.2.2) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\lib\site-packages (from pooch->pyvista->quantum_electron==0.2.2) (2.32.2)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->quantum_electron==0.2.2) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->quantum_electron==0.2.2) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->quantum_electron==0.2.2) (0.2.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista->quantum_electron==0.2.2) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->pyvista->quantum_electron==0.2.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->pyvista->quantum_electron==0.2.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->pyvista->quantum_electron==0.2.2) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->pyvista->quantum_electron==0.2.2) (2024.6.2)
# Using cached alive_progress-3.3.0-py3-none-any.whl (78 kB)
# Using cached about_time-4.2.1-py3-none-any.whl (13 kB)
# Using cached graphemeu-0.7.2-py3-none-any.whl (22 kB)
# Downloading pyvista-0.46.4-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.4 MB 9.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.7/2.4 MB 8.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.4 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.9/2.4 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 10.4 MB/s eta 0:00:00
# Downloading shapely-2.1.2-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.7 MB 18.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 13.7 MB/s eta 0:00:00
# Downloading scooby-0.11.0-py3-none-any.whl (19 kB)
# Downloading vtk-9.5.2-cp312-cp312-win_amd64.whl (64.0 MB)
#    ---------------------------------------- 0.0/64.0 MB ? eta -:--:--
#     --------------------------------------- 1.0/64.0 MB 21.8 MB/s eta 0:00:03
#    - -------------------------------------- 2.0/64.0 MB 21.2 MB/s eta 0:00:03
#    - -------------------------------------- 3.1/64.0 MB 22.2 MB/s eta 0:00:03
#    -- ------------------------------------- 4.2/64.0 MB 22.4 MB/s eta 0:00:03
#    --- ------------------------------------ 5.1/64.0 MB 21.7 MB/s eta 0:00:03
#    --- ------------------------------------ 6.3/64.0 MB 23.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 7.5/64.0 MB 22.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 8.3/64.0 MB 23.0 MB/s eta 0:00:03
#    -------------------------------------- - 61.4/64.0 MB 14.5 MB/s eta 0:00:01
#    -------------------------------------- - 62.1/64.0 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  62.7/64.0 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  63.4/64.0 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  63.9/64.0 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  64.0/64.0 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  64.0/64.0 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  64.0/64.0 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  64.0/64.0 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 64.0/64.0 MB 11.1 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: shapely, scooby, graphemeu, about-time, pooch, alive_progress, vtk, pyvista, quantum_electron
#   Running setup.py develop for quantum_electron
# Successfully installed about-time-4.2.1 alive_progress-3.3.0 graphemeu-0.7.2 pooch-1.8.2 pyvista-0.46.4 quantum_electron-0.2.2 scooby-0.11.0 shapely-2.1.2 vtk-9.5.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script scooby.exe is installed in 'C:\Users\gordi\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install -e ./lib/zeroheliumkit_0.5.0_win
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///C:/Users/gordi/Princeton%20Dropbox/Gordian%20Fuchs/GroupDropbox/Gordian/Python/zeroHeliumKitSimulations/Gordian/lib/zeroheliumkit_0.5.0_win
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Installing collected packages: zeroheliumkit
#   Running setup.py develop for zeroheliumkit
# Successfully installed zeroheliumkit-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Imports

# %%
import os
import sys
import yaml
import numpy as np
import matplotlib.pyplot as plt

from zeroheliumkit import Structure, Rectangle, GeomCollection
from zeroheliumkit.src.importing import Reader_GDS,Reader_DXF,Reader_Pickle
from zeroheliumkit.fem import *
from zeroheliumkit.src.settings import  *

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plot_config = {'wafer':BLACK,'bottom':YELLOW2,'extra':GRAY,'top':(BLUE,0.6)}

# %% [markdown]
# # Device Importing

# %%
# Read File
file = Reader_GDS('reduced_2.gds')
file.import2zhk("TOP")
device = GeomCollection(file.geometries)

#Add a "wafer" Layer
device.add_layer('wafer', Rectangle(30,30,(0,0)))

# Rename Layers
device.rename_layer('L0','extra')
device.rename_layer('L22','bottom')
device.rename_layer('L28','top')
device.layers

#Show Device
device.quickplot(plot_config)
# Out:
# reduced_2.gds // Layers in cell 'TOP': {0, 28, 22}
# <Axes: >

# %% [markdown]
# # Viewing Electrodes

# %%
for layer in ["extra","bottom","top"]:
    fig = plt.figure(1, figsize=(5,5), dpi=90)
    ax = fig.add_subplot(111)
    device.plot(ax=ax, layer=[layer],color=[RED],show_idx=True)
    plt.show()

# %% [markdown]
# # Define 3D Geometry

# %%
d_metal1 = 0.900
d_metal2 = 0.250
d_diel  = 0.900
d_vac   = 25
d_He    = d_diel + d_metal2
d_total = d_metal1 + d_He

extrude_config = {
    'wafer' :       gmshLayer_info('wafer'    , -d_vac/2 , d_vac/2         , 'DIELECTRIC'),
    'bottom':       gmshLayer_info('bottom'   , 0 , d_metal1               , 'METAL'),
    'extra':        gmshLayer_info('extra'    , 0 , d_metal1               , 'METAL'),
    'dielectric':   gmshLayer_info('top'      , d_metal1 , d_diel          , 'DIELECTRIC'),
    'top':          gmshLayer_info('top'      , d_metal1+d_diel, d_metal2  , 'METAL'),
    'helium':       gmshLayer_info('wafer'    , d_metal1, d_He             , 'HELIUM', ('dielectric','top')),
    'vacuum':       gmshLayer_info('wafer'    , d_metal1+d_He, d_vac       , 'VACUUM', ('dielectric', 'top'))
}

electrodes_config = {
    'Door1':        physSurface_info('bottom',   [0], 'bottom'),
    'Sense':        physSurface_info('bottom',   [1], 'bottom'),
    'Guard':        physSurface_info('bottom',   [2], 'bottom'),
    'Twiddle':      physSurface_info('bottom',   [3], 'bottom'),
    'Door2':        physSurface_info('bottom',   [4], 'bottom'),
    'Top':          physSurface_info('top',    [0,1], 'top'),
    'Extra':        physSurface_info('extra',    [0], 'extra'),
}

mediumregion_box = [-12, 12, -5, 5, -0.7, 6]
fineregion_box = [-8, 8, -2.5, 2.5, -0.1, 4.5]
scale = 4
mesh_params = [{"Thickness": 4, "VIn": scale * 0.2, "VOut": .5*scale, "box": mediumregion_box},
               {"Thickness": 2, "VIn": scale * 0.1, "VOut": .5*scale, "box": fineregion_box}
              ]

# %% [markdown]
# # Generate Mesh

# %%
save_dir = 'dump/'
mshID = 'GordianSensor'
meshMKR =  GMSHmaker(layout=device, 
                     extrude_config=extrude_config, 
                     electrodes_config=electrodes_config, 
                     mesh_params=mesh_params)
meshMKR.create_geo(save_dir+mshID )
meshMKR.create_mesh(save_dir+mshID, dim=3)
meshMKR.open_gmsh()
meshMKR.finalize()
# Out:
# on 0: mesh is constructed
# on 0: mesh saved
# Gmsh generation  |███| 1/1 [100%] in 1.8s (0.57/s)

# %% [markdown]
# # Create edp file

# %%
He_level = round(d_total,3)

var_eps = {
        'DIELECTRIC': 11.0,
        'METAL': 1.0,
        'HELIUM': 1.057,
        'VACUUM': 1.0,
}

ff_config ={
    'meshfile': save_dir+mshID,
    'dielectric_constants': var_eps,
    'ff_polynomial': 2,
    'extract_opt': [extract_results('phi', 'xy', (-8, 8,1001), (-2.1, 2.1,201), He_level,'twiddleSense'),
                    ],
    'physicalSurfaces': {k: v.get('group_id') for (k, v) in meshMKR.physicalSurfaces.items()},
    'physicalVolumes': {k: v.get('group_id') for (k, v) in meshMKR.physicalVolumes.items()}
}

with open(save_dir+r'config.yaml', 'w') as file:
    documents = yaml.safe_dump(ff_config, file)

# %%
with open(save_dir+r'config.yaml', 'r') as file:
    config = yaml.safe_load(file)

yff = FreeFEM(config=config,
               dirname='./',
               run_from_notebook=False)

# %% [markdown]
# Then in a terminal, cd to this folder and run: "freefem++ ./dump/GordianSensor.edp"
