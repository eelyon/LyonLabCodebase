# %%
pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Obtaining file:///C:/Users/Kyle/Downloads/gordian/quantum_electron-main/quantum_electron-main
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 38.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 12.9/12.9 MB 104.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 60.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/64.0 MB ? eta -:--:--
#    ----------- ---------------------------- 19.1/64.0 MB 102.7 MB/s eta 0:00:01
#    ------------------------- -------------- 40.6/64.0 MB 101.4 MB/s eta 0:00:01
# ...
